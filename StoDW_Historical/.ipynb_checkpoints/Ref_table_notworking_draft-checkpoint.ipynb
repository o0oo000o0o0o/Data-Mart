# %%
import pandas as pd
import numpy as np
import psycopg2
import time

# %%
#Psycopg2 Connections
#PostgreSQL Connection
try:
    pg_db = psycopg2.connect(host="165.22.220.96",user="praveen",password="Admin123",database="staging")
    pg_db.autocommit = True
    pgcursor = pg_db.cursor()
    print("PostgreSQL Connection Established")
except psycopg2.OperationalError as e:
    print("Unable to Connect: ",format(e))

# PostgreSQL Connection 1
try:
    pg_db1 = psycopg2.connect(host="165.22.220.96",user="praveen",password="Admin123",database="staging")
    pg_db1.autocommit = True
    pgcursor1 = pg_db1.cursor()
    print("PostgreSQL Connection Established")
except psycopg2.OperationalError as e:
    print("Unable to Connect: ",format(e))
    
# #PostgreSQL Connection 2
try:
    pg_db2 = psycopg2.connect(host="165.22.220.96",user="praveen",password="Admin123",database="staging")
    pg_db2.autocommit = True
    pgcursor2 = pg_db2.cursor()
    print("PostgreSQL Connection Established")
except psycopg2.OperationalError as e:
    print("Unable to Connect: ",format(e))

# PostgreSQL Connection 3
try:
    pg_db3 = psycopg2.connect(host="165.22.220.96",user="praveen",password="Admin123",database="staging")
    pg_db3.autocommit = True
    pgcursor3 = pg_db3.cursor()
    print("PostgreSQL Connection Established")
except psycopg2.OperationalError as e:
    print("Unable to Connect: ",format(e))
    
# #PostgreSQL Connection 4
try:
    pg_db4 = psycopg2.connect(host="165.22.220.96",user="praveen",password="Admin123",database="staging")
    pg_db4.autocommit = True
    pgcursor4 = pg_db4.cursor()
    print("PostgreSQL Connection Established")
except psycopg2.OperationalError as e:
    print("Unable to Connect: ",format(e))
    
# PostgreSQL Connection 5
try:
    pg_db5 = psycopg2.connect(host="165.22.220.96",user="praveen",password="Admin123",database="staging")
    pg_db5.autocommit = True
    pgcursor5 = pg_db5.cursor()
    print("PostgreSQL Connection Established")
except psycopg2.OperationalError as e:
    print("Unable to Connect: ",format(e))
    
# #PostgreSQL Connection 6
try:
    pg_db6 = psycopg2.connect(host="165.22.220.96",user="praveen",password="Admin123",database="staging")
    pg_db6.autocommit = True
    pgcursor6 = pg_db6.cursor()
    print("PostgreSQL Connection Established")
except psycopg2.OperationalError as e:
    print("Unable to Connect: ",format(e))
    
# PostgreSQL Connection 7
try:
    pg_db7 = psycopg2.connect(host="165.22.220.96",user="praveen",password="Admin123",database="staging")
    pg_db7.autocommit = True
    pgcursor7 = pg_db7.cursor()
    print("PostgreSQL Connection Established")
except psycopg2.OperationalError as e:
    print("Unable to Connect: ",format(e))
    
# #PostgreSQL Connection 8
try:
    pg_db8 = psycopg2.connect(host="165.22.220.96",user="praveen",password="Admin123",database="staging")
    pg_db8.autocommit = True
    pgcursor8 = pg_db8.cursor()
    print("PostgreSQL Connection Established")
except psycopg2.OperationalError as e:
    print("Unable to Connect: ",format(e))
    
# PostgreSQL Connection 9
try:
    pg_db9 = psycopg2.connect(host="165.22.220.96",user="praveen",password="Admin123",database="staging")
    pg_db9.autocommit = True
    pgcursor9 = pg_db9.cursor()
    print("PostgreSQL Connection Established")
except psycopg2.OperationalError as e:
    print("Unable to Connect: ",format(e))
    
# # #PostgreSQL Connection 10
# try:
#     pg_db10 = psycopg2.connect(host="165.22.220.96",user="praveen",password="Admin123",database="staging")
#     pg_db10.autocommit = True
#     pgcursor10 = pg_db10.cursor()
#     print("PostgreSQL Connection Established")
# except psycopg2.OperationalError as e:
#     print("Unable to Connect: ",format(e))

# %%
#Select 
slt_cmd_mc = "select master_customer_id,email_address from master_customer_test"

slt_cmd_ref = "select master_customer_id from dw_ref_source_dim"

slt_cmd_blc = "select email_address from stg_customer"
slt_cmd_crm = "select email_address from stg_crm_customer"
slt_cmd_bpm = "select email from stg_bpm_client_info"

insrt_cmd = """insert into dw_ref_source_dim (master_customer_id, source_id)
                values ( """


pgcursor.execute(slt_cmd_mc)
pgcursor9.execute(slt_cmd_crm)
for x in pgcursor:
    print(x[1])
    pgcursor1.execute(slt_cmd_ref)
    if x[0] not in pgcursor1:
        print("Checking Source tables")
#         pgcursor3.execute(slt_cmd_blc)
#         for peeps in pgcursor3:
#             print(peeps)
#         pgcursor7.execute(slt_cmd_bpm)

        if x[1] in pgcursor9:
            print("yes in 9")
#         elif x[1] in pgcursor7:
#             print("yes in 7")
#         elif x[1] in pgcursor9:
#             print("yes in 9")
        else:
            print("goodbye")
#         if x[1] in pgcursor3:
#             print("running pgcursor3")
#             pgcursor2.execute(insrt_cmd5+str(x[0])+", "+str(1)+")")
#             pgcursor4.execute(slt_cmd_bpm)
#             pgcursor6.execute(slt_cmd_crm)
#             if x[1] in pgcursor4:
#                 print("running pgcursor4")
#                 pgcursor2.execute(insrt_cmd5+str(x[0])+", "+str(2)+")")
#                 pgcursor5.execute(slt_cmd_crm)
#                 if x[1] in pgcursor5:
#                     print("running pgcursor5")
#                     pgcursor2.execute(insrt_cmd5+str(x[0])+", "+str(3)+")")
#                     print("Done!")
#             elif x[1] in pgcursor6:
#                 print("running pgcursor6")
#                 pgcursor2.execute(insrt_cmd5+str(x[0])+", "+str(3)+")")
#                 print("Done!")
#         elif x[1] in pgcursor7:
#             print("running pgcursor7")
#             pgcursor2.execute(insrt_cmd5+str(x[0])+", "+str(2)+")")
#             pgcursor8.execute(slt_cmd_crm)
#             if x[1] in pgcursor8:
#                 print("running pgcursor8")
#                 pgcursor2.execute(insrt_cmd5+str(x[0])+", "+str(3)+")")
#                 print("Done!")
#         elif x[1] in pgcursor9:
#             print("running pgcursor9")
#             pgcursor2.execute(insrt_cmd5+str(x[0])+", "+str(3)+")")
#             print("Done!")
#     else:
#         print("Record already exists in Reference Table")
    
    
pg_db.close()
pg_db1.close()    
pg_db2.close()
pg_db3.close()
pg_db4.close()    
pg_db5.close()
pg_db6.close()
pg_db7.close()    
pg_db8.close()
pg_db9.close()

# %%
# slt_cmd_mc = "select master_customer_id,email_address from master_customer_test"
# slt_cmd_ref = "select master_customer_id from dw_ref_source_dim"
# slt_cmd_blc = "select email_address from stg_customer"
# pgcursor.execute(slt_cmd_mc)

# for x in pgcursor:
#     print(x[0])
#     pgcursor1.execute(slt_cmd_ref)
#     if x[0] not in (pgcursor1):
#         print("Checking Source tables")
#         pgcursor2.execute(slt_cmd_blc)
#         if x[1] in (pgcursor2):
#             print("Hello")
#         else:
#             print("goodbye")

# %%
slt_cmd_blc = """select mc.master_customer_id
                        from master_customer_test AS mc, stg_customer AS C
                        WHERE mc.email_address = C.email_address"""

slt_cmd_blc = """select mc.master_customer_id
                        from master_customer_test AS mc, stg_bpm_client_info AS C
                        WHERE mc.email_address = C.email"""

slt_cmd_blc = """select mc.master_customer_id
                        from master_customer_test AS mc, stg_crm_customer AS C
                        WHERE mc.email_address = C.email_address"""

insrt_cmd_blc = """insert into dw_ref_source_dim (master_customer_id, source_id)
                values ( """

pgcursor.execute(slt_cmd)
for x in pgcursor :
    print(x[0])
    print(insrt_cmd5+str(x[0])+", "+str(1)+")")
    pgcursor1.execute(insrt_cmd5+str(x[0])+", "+str(1)+")")

pgcursor.execute(slt_cmd)
for x in pgcursor :
    print(x[0])
    print(insrt_cmd5+str(x[0])+", "+str(1)+")")
    pgcursor1.execute(insrt_cmd5+str(x[0])+", "+str(1)+")")
    
pgcursor.execute(slt_cmd)
for x in pgcursor :
    print(x[0])
    print(insrt_cmd5+str(x[0])+", "+str(1)+")")
    pgcursor1.execute(insrt_cmd5+str(x[0])+", "+str(1)+")")

# %%
# inst_cmd = """INSERT INTO dw_ref_source_dim (master_customer_id,email_address)
#                 SELECT master_customer_id,email_address
#                 FROM master_customer_test;"""

# upd_cmd_blc = """update dw_ref_source_dim
#                 SET blc_customer_id = (select customer_id from stg_customer
#                 where dw_ref_source_dim.email_address = stg_customer.email_address and (role_id = 1 and address_line1 is not null))"""

# upd_cmd_bpm = """update dw_ref_source_dim
#                 SET bpm_customer_id = (select clientid from stg_bpm_client_info
#                 where dw_ref_source_dim.email_address = stg_bpm_client_info.email and address is not null limit 1);"""

# upd_cmd_crm = """update dw_ref_source_dim
#                 SET crm_customer_id = (select customer_id from stg_crm_customer
#                 where dw_ref_source_dim.email_address = stg_crm_customer.email_address and address1 is not null limit 1);"""

# pgcursor.execute(inst_cmd)
# pgcursor.execute(upd_cmd_blc)
# pgcursor.execute(upd_cmd_bpm)
# pgcursor.execute(upd_cmd_crm)

# pg_db.close()

# %%
# #Insert master customer ids into reference source dim
# inst_cmd = """INSERT INTO dw_ref_source_dim (master_customer_id)
#                 SELECT master_customer_id
#                 FROM master_customer_test;"""


# #Update source_id for blc records in reference table
# upd_cmd_blc = """UPDATE dw_ref_source_dim 
#                     SET source_id = 1
#                     where dw_ref_source_dim.master_customer_id IN (select master_customer_test.master_customer_id
#                     from master_customer_test, stg_customer
#                     WHERE master_customer_test.email_address = stg_customer.email_address)"""


# #Update source_id for bpm records in reference table
# upd_cmd_blc = """UPDATE dw_ref_source_dim 
#                     SET source_id = 2
#                     where dw_ref_source_dim.master_customer_id IN (select master_customer_test.master_customer_id
#                     from master_customer_test, stg_bpm_client_info
#                     WHERE master_customer_test.email_address = stg_bpm_client_info.email_address)"""

# #Update source_id for crm records in reference table
# upd_cmd_blc = """UPDATE dw_ref_source_dim 
#                     SET source_id = 3
#                     where dw_ref_source_dim.master_customer_id IN (select master_customer_test.master_customer_id
#                     from master_customer_test, stg_crm_customer
#                     WHERE master_customer_test.email_address = stg_crm_customer.email_address)"""

# %%
# first loop: 
#     iterate through all email addresses from de-duplicated master table

#     second loop:
#         do count(*) duplicate master_table where email_address = email from first loop

# %%
# #Select 
# slt_cmd_mc = "select master_customer_id,email_address from master_customer_test"

# slt_cmd_ref = "select master_customer_id from dw_ref_source_dim"

# slt_cmd_blc = "select email_address from stg_customer"
# slt_cmd_bpm = "select email_address from stg_crm_customer"
# slt_cmd_crm = "select email from stg_bpm_client_info"

# insrt_cmd = """insert into dw_ref_source_dim (master_customer_id, source_id)
#                 values ( """


# pgcursor.execute(slt_cmd_mc)
# for x in pgcursor:
# #     pgcursor1.execute(slt_cmd_ref)
#     if x[0] not in pgcursor1.execute(slt_cmd_ref):
#         print("Checking Source tables")
#         if x[1] in pgcursor2.execute(slt_cmd_blc):
#             print("In BLC")
#             pgcursor2.execute(insrt_cmd5+str(x[0])+", "+str(1)+")")
#             if x[1] in pgcursor1.execute(slt_cmd_bpm):
#                 pgcursor2.execute(insrt_cmd5+str(x[0])+", "+str(2)+")")
#                 if x[1] in pgcursor1.execute(slt_cmd_crm):
#                     pgcursor2.execute(insrt_cmd5+str(x[0])+", "+str(3)+")")
#                     print("Done!")
#             elif x[1] in pgcursor1.execute(slt_cmd_crm):
#                 pgcursor2.execute(insrt_cmd5+str(x[0])+", "+str(3)+")")
#                 print("Done!")
#         elif x[1] in pgcursor1.execute(slt_cmd_bpm):
#             pgcursor2.execute(insrt_cmd5+str(x[0])+", "+str(2)+")")
#             if x[1] in pgcursor1.execute(slt_cmd_crm):
#                 pgcursor2.execute(insrt_cmd5+str(x[0])+", "+str(3)+")")
#                 print("Done!")
#         elif x[1] in pgcursor1.execute(slt_cmd_crm):
#             pgcursor2.execute(insrt_cmd5+str(x[0])+", "+str(3)+")")
#             print("Done!")
#     else:
#         print("Record already exists in Reference Table")
    
    
# pg_db.close()
# pg_db1.close()    
# pg_db2.close()
