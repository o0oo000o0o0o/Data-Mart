# %%
#CREATE TABLES IN POSTGRE DB

CREATE TABLE IF NOT EXISTS BLC_Conversion_Order_Master (
     CONVERSION_ORDER_ID INT NOT NULL,
     ADDITIONAL_DESIGN_INFO TEXT,
     AMOUNT_PAID NUMERIC,
     AUTHOR_FIRSTNAME VARCHAR(255),
     AUTHOR_LASTNAME VARCHAR(255),
     BACK_COVER_DESIGN TEXT,
     DO_YOU_HAVE_BOOK_COVER INT,
     BOOK_DESCRIPTION TEXT,
     BOOK_LINKS TEXT,
     COLOR_PREFERENCE TEXT,
     ESTIMATED_ARRIVAL TIMESTAMP,
     FRONT_COVER_DESIGN TEXT,
     ORDER_DATE TIMESTAMP,
     ORDER_STATUS VARCHAR(255),
     ORDER_STATUS_DATE VARCHAR(255),
     ORDER_TYPE VARCHAR(255),
     PAYMENT_OPTION VARCHAR(255),
     PRICE NUMERIC,
     ROUGH_MOCKUP INT,
     SECONDARY_TEXT TEXT,
     SHIPPING_COST NUMERIC,
     SUB_TITLE VARCHAR(255),
     TITLE VARCHAR(255),
     BOOK_TYPE INT,
     OTHER_SERVICES INT,
     CUSTOMIZE_EBOOK_ID INT,
     CUSTOMIZE_PRINT_BOOK_ID INT,
     GENRE INT,
     ID INT,
     ORDER_CART_ID INT,
     OTHER_CUSTOMIZATIONS_ID INT,
     ADDITIONAL_AMOUNT NUMERIC,
     CREATED_DATE TIMESTAMP,
     UPDATED_DATE TIMESTAMP,
     PRIMARY KEY (CONVERSION_ORDER_ID)
);

CREATE TABLE IF NOT EXISTS stg_blc_Customer (
     CUSTOMER_ID INT NOT NULL,
     CREATED_BY INT,
     DATE_CREATED TIMESTAMP,
     DATE_UPDATED TIMESTAMP,
     UPDATED_BY INT,
     CHALLENGE_ANSWER VARCHAR(25),
     DEACTIVATED INT,
     EMAIL_ADDRESS VARCHAR(255),
     FIRST_NAME VARCHAR(255),
     LAST_NAME VARCHAR(255),
     PASSWORD VARCHAR(255),
     PASSWORD_CHANGE_REQUIRED INT,
     IS_PREVIEW INT,
     RECEIVE_EMAIL INT,
     IS_REGISTERED INT,
     TAX_EXEMPTION_CODE VARCHAR(255),
     USER_NAME VARCHAR(255),
     CHALLENGE_QUESTION_ID INT,
     LOCALE_CODE VARCHAR(225),
     STATUS INT,
     DEFAULT_ADDRESS_ID INT,
     ADDRESS_LINE1 VARCHAR(255),
     CITY VARCHAR(255),
     PHONE VARCHAR(255),
     ZIP VARCHAR(255),
     COUNTRY INT,
     STATE INT,
     ROLE_ID INT,
     IS_PUBLISHER INT,
     PUBLISHER_NAME VARCHAR(255),
     REGISTERED_DATE VARCHAR(255),
     WEBSITE VARCHAR(255),
     AGREEMENT_STATUS INT,
     IS_PARTNER INT,
     DATE_OF_SALE TIMESTAMP,
     ACTIVITY_LOG VARCHAR(255),
     LEAD_OWNER INT,
     LEAD_SOURCE VARCHAR(255),
     ORDER_TYPE VARCHAR(255),
     CREATED_DATE TIMESTAMP,
     UPDATED_DATE TIMESTAMP,
    COUNTRY_NAME VARCHAR(255),
    STATE_NAME VARCHAR(255),
     PRIMARY KEY (CUSTOMER_ID)
);

CREATE TABLE IF NOT EXISTS BLC_Distribution_OrderInfo (
     Distribution_OrderInfo_ID INT NOT NULL,
     ISBN VARCHAR(255) NOT NULL,
     ARCHIVED VARCHAR(255),
     BACK_COVER VARCHAR(255),
     EBOOK VARCHAR(255),
     FRONT_COVER VARCHAR(255),
     LIST_PRICE VARCHAR(255) NOT NULL,
     ORDER_STATUS VARCHAR(255),
     ORDER_STATUS_DATE VARCHAR(255),
     ORDER_REMARKS VARCHAR(2000),
     TITLE VARCHAR(255),
     DISTRIBUTION_ORDER_INSTORES_ID INT,
     DISTRIBUTION_METADATA_ID INT,
     ID INT,
     ORDER_DATE TIMESTAMP,
     CCID VARCHAR(255),
     FORMAT VARCHAR(255),
     GCCID INT,
     UPDATED_STATUS INT,
     MOBI_ISBN VARCHAR(255),
     PDF_ISBN VARCHAR(255),
     PRINT_ISBN VARCHAR(255),
     MOBI VARCHAR(255),
     PDF VARCHAR(255),
     CREATED_DATE TIMESTAMP,
     UPDATED_DATE TIMESTAMP,
     PRIMARY KEY (Distribution_OrderInfo_ID)
);


CREATE TABLE IF NOT EXISTS BLC_Orders (
     ORDER_ID INT NOT NULL,
     CREATED_BY INT,
     DATE_CREATED TIMESTAMP,
     DATE_UPDATED TIMESTAMP,
     UPDATED_BY INT,
     EMAIL_ADDRESS VARCHAR(255),
     NAME VARCHAR(255),
     ORDER_NUMBER VARCHAR(255),
     IS_PREVIEW INT,
     ORDER_STATUS VARCHAR(255),
     ORDER_SUBTOTAL NUMERIC(19,5),
     SUBMIT_DATE TIMESTAMP,
     TAX_OVERRIDE INT,
     ORDER_TOTAL NUMERIC(19,5),
     TOTAL_SHIPPING NUMERIC(19,5),
     TOTAL_TAX NUMERIC(19,5),
     CURRENCY_CODE VARCHAR(255),
     CUSTOMER_ID INT NOT NULL,
     LOCALE_CODE VARCHAR(255),
     CONVERSION_ORDER_STATUS VARCHAR(255),
     CONVERSION_ORDER_TITLE VARCHAR(255),
     CONVERSION_ORDER_DETAILS_ID INT,
     ORDER_BALENCE NUMERIC(19,5),
     PAYMENT_STATUS VARCHAR(255),
     INVOICE_ID INT,
     QUOTE_ID INT,
     CREATED_DATE TIMESTAMP,
     UPDATED_DATE TIMESTAMP,
     PRIMARY KEY (ORDER_ID),
     FOREIGN KEY (CUSTOMER_ID)
         REFERENCES BLC_CUSTOMER (CUSTOMER_ID)
);


CREATE TABLE IF NOT EXISTS BLC_SALESREPORTS (
     SALES_ID INT NOT NULL,
     DATE_OF_SALE TIMESTAMP,
     COUNTRY_OF_SALE VARCHAR(255),
     CUSTOMER_CURRENCY VARCHAR(255),
     CUSTOMER_SHARE NUMERIC,
     DELIVARY_COST NUMERIC,
     DISCOUNT NUMERIC,
     EBOOKS_SHARE NUMERIC,
     FILE_SIZE NUMERIC,
     FINAL_PRICE NUMERIC,
     NET_UNITS INT,
     QUANTITY_OF_SALE INT,
     STORE_PRICE NUMERIC,
     UNITS_RETURNED INT,
     DISTRIBUTION_ORDERINFO_ID INT NOT NULL,
     CUSTOMER_ID INT NOT NULL,
     STORE_ID INT NOT NULL,
     FORMAT VARCHAR(45),
     CREATED_DATE TIMESTAMP,
     UPDATED_DATE TIMESTAMP,
     PRIMARY KEY (SALES_ID)
);


CREATE TABLE IF NOT EXISTS BLC_STORES (
     STORE_ID INT NOT NULL,
     STORE_NAME VARCHAR(255),
     STORE_IMAGE VARCHAR(255),
     STORE_ROYALTY VARCHAR(255),
     CREATED_DATE TIMESTAMP,
     UPDATED_DATE TIMESTAMP,
     PRIMARY KEY (STORE_ID)
);


CREATE TABLE IF NOT EXISTS BPM_client_info (
    clientid int,
    company_name varchar(200),
    address varchar(426),
    city varchar(128),
    state varchar(128),
    country varchar(128),
    zip varchar(32),
    phone varchar(32),
    fax varchar(32),
    email varchar(164),
    w9number varchar(64),
    date TIMESTAMP,
    CREATED_DATE TIMESTAMP,
    UPDATED_DATE TIMESTAMP,    
    PRIMARY KEY (clientid)
    );


CREATE TABLE IF NOT EXISTS CRM_customer (
    Customer_id int,
    Email_Address varchar(220),
    Date_Created varchar(60),
    Given_name varchar(220),
    Address1 varchar(220),
    Address2 varchar(45),
    Locality varchar(220),
    Region varchar(45),
    Postal_code varchar(45),
    ZIP_Code varchar(45),
    Country_code varchar(45),
    Phonenumber varchar(45),
    Email_status varchar(45),
    CREATED_DATE TIMESTAMP,
    UPDATED_DATE TIMESTAMP,
    PRIMARY KEY (Customer_id)
    );


CREATE TABLE IF NOT EXISTS BLC_COUNTRIES (
    COUNTRY_ID INT, 
    COUNTRY_FLAG varchar(255),
    COUNTRY_NAME varchar(255),
    PHONE_CODE varchar(255),
    COUNTRY_CODE varchar(10),
    CREATED_DATE TIMESTAMP,
    UPDATED_DATE TIMESTAMP,
    PRIMARY KEY (COUNTRY_ID)
);


CREATE TABLE IF NOT EXISTS BLC_STATES (
    STATE_ID INT, 
    COUNTRY_ID INT,
    STATE_NAME varchar(255),
    CREATED_DATE TIMESTAMP,
    UPDATED_DATE TIMESTAMP,
    PRIMARY KEY (STATE_ID)
);

CREATE TABLE IF NOT EXISTS stg_BLC_Distribution_Order_Metadata (
    DISTRIBUTION_ORDER_METADATA_ID INT NOT NULL,
    DO_YOU_WANT_DRM INT,
    AGE_GROUP varchar(255),
    BISAC text,
    CONTRIBUTOR_FIVE_DETAILS text,
    CONTRIBUTOR_FIVE_FIRST_NAME varchar(255),
    CONTRIBUTOR_FIVE_LAST_NAME varchar(255),
    CONTRIBUTOR_FIVE_ROLE varchar(255),
    CONTRIBUTOR_FOUR_DETAILS text,
    CONTRIBUTOR_FOUR_FIRST_NAME varchar(255),
    CONTRIBUTOR_FOUR_LAST_NAME varchar(255),
    CONTRIBUTOR_FOUR_ROLE varchar(255),
    CONTRIBUTOR_ONE_DETAILS text,
    CONTRIBUTOR_ONE_FIRST_NAME varchar(255),
    CONTRIBUTOR_ONE_LAST_NAME varchar(255),
    CONTRIBUTOR_ONE_ROLE varchar(255),
    CONTRIBUTOR_THREE_DETAILS text,
    CONTRIBUTOR_THREE_FIRST_NAME varchar(255),
    CONTRIBUTOR_THREE_LAST_NAME varchar(255),
    CONTRIBUTOR_THREE_ROLE varchar(255),
    CONTRIBUTOR_TWO_DETAILS text,
    CONTRIBUTOR_TWO_FIRST_NAME varchar(255),
    CONTRIBUTOR_TWO_LAST_NAME varchar(255),
    CONTRIBUTOR_TWO_ROLE varchar(255),
    COPY_RIGHT varchar(255),
    ROYALTY varchar(250),
    EDITORIAL_CONTENT text,
    EDITORIAL_FIRST_NAME varchar(255),
    EDITORIAL_LAST_NAME varchar(255),
    EXPECTED_PUBLISHING_DATE varchar(255),
    KEY_WORDS text,
    LANGUAGE varchar(255),
    IS_PRINTABLE INT,
    IS_PUBLIC_DOMAIN INT,
    PUBLISHER varchar(255),
    EBOOK_DESCRIPTION text,
    SERIES varchar(255),
    TERRITORY text,
    DISTRIBUTION_ORDERINFO_ID INT NOT NULL
    CREATED_DATE TIMESTAMP,
    UPDATED_DATE TIMESTAMP,
    PRIMARY KEY (DISTRIBUTION_ORDER_METADATA_ID)
);

CREATE TABLE IF NOT EXISTS stg_overdrive_sales (
    Date TIMESTAMP,
    OverDrive_ID BIGINT NOT NULL,
    ISBN VARCHAR(255),
    Title varchar(255),
    Subtitle varchar(255),
    Author varchar(255),
    Retailer varchar(255),
    Country_of_sale varchar(5),
    Format varchar(100),
    SRP_USD Numeric,
    Discount Numeric,
    Amt_owed_USD Numeric,
    CREATED_DATE TIMESTAMP,
    UPDATED_DATE TIMESTAMP
);
