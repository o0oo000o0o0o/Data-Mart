# %%
from airflow import DAG
from airflow.operators import DummyOperator, BashOperator

default_args = {'owner' = 'airflow'}

dag = DAG('HistoricalLtoSTest', schedule_interval = '@once')

task_1 = BashOperator(task_id = 'start_task',
     bash_command = 'echo start_task',
     dag = dag)

task_2 = BashOperator(task_id = 'BLC_Stores', 
dag = dag,
bash_command = 'python /root/Mahathi/LtoSHistorical/SA_BLC_Stores.py',
default_args = default_args)

task_3 = BashOperator(task_id = 'BLC_States', 
dag = dag,
bash_command = 'python /root/Mahathi/LtoSHistorical/SA_BLC_STATES.py',
default_args = default_args)

task_4 = BashOperator(task_id = 'BLC_Countries', 
dag = dag,
bash_command = 'python /root/Mahathi/LtoSHistorical/SA_BLC_COUNTRIES.py',
default_args = default_args)

task_5 = BashOperator(task_id = 'BLC_Order', 
dag = dag,
bash_command = 'python /root/Mahathi/LtoSHistorical/SA_BLC_ORDERS.py',
default_args = default_args)

task_6 = BashOperator(task_id = 'ConversionOrderMaster', 
dag = dag,
bash_command = 'python /root/Mahathi/LtoSHistorical/SA_BLC_CONVERSION_ORDER_MASTER.py',
default_args = default_args)

task_7 = BashOperator(task_id = 'DistributionOrderInfo', 
dag = dag,
bash_command = 'python /root/Mahathi/LtoSHistorical/SA_BLC_DISTRIBUTION_ORDERINFO.py',
default_args = default_args)

task_8 = BashOperator(task_id = 'BPM_ClientInfo', 
dag = dag,
bash_command = 'python /root/Mahathi/LtoSHistorical/SA_BPM_CLIENTINFO.py',
default_args = default_args)

task_9 = BashOperator(task_id = 'CRM_Customer', 
dag = dag,
bash_command = 'python /root/Mahathi/LtoSHistorical/SA_CRM_CUSTOMER.py',
default_args = default_args)

task_10 = BashOperator(task_id = 'BLC_Customer', 
dag = dag,
bash_command = 'python /root/Mahathi/LtoSHistorical/SA_BLC_Customer.py',
default_args = default_args)

task_11 = BashOperator(task_id = 'BLC_Sales', 
dag = dag,
bash_command = 'python /root/Mahathi/LtoSHistorical/SA_BLC_SALESREPORTS.py',
default_args = default_args)

task_12 = DummyOperator(task_id='End_task')

#Task Order
task_1 >> task_2 >> task_3 >> task_4 >> task_5 >> task_6 >> task_7 >> task_8 >> task_9 >> task_10 >> task_11 >> task_12
